# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Loading dataset.
honey = pd.read_csv('vHoneyNeonic_v03.csv')

# %%
print(honey)
# Out:
#      state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0       AL  14000.0           66   924000.0   92000.0        0.81   748000.0
# 1       AL  15000.0           64   960000.0   96000.0        0.87   835000.0
# 2       AL  16000.0           58   928000.0   28000.0        0.69   640000.0
# 3       AL  18000.0           50   900000.0   99000.0        0.52   468000.0
# 4       AL  19000.0           45   855000.0  103000.0        0.59   504000.0
# 5       AL  23000.0           24   552000.0   66000.0        0.63   348000.0
# 6       AL  25000.0           41  1025000.0  113000.0        0.59   605000.0
# 7       AL  11000.0           56   616000.0  209000.0        1.49   918000.0
# 8       AL  11000.0           72   792000.0  230000.0        1.21   958000.0
# 9       AL  12000.0           86  1032000.0  103000.0        1.18  1218000.0
# 10      AL  12000.0           87  1044000.0  282000.0        1.41  1472000.0
# ...

# %%
sns.set(style="ticks")
sns.regplot(honey.nAllNeonic, honey.yieldpercol)

# %%
fig, ax = plt.subplots()
ax = sns.pointplot(honey.year, honey.yieldpercol)
fig.set_size_inches(16,4)

# %%
fig, ax = plt.subplots()
ax = sns.barplot(honey.year, honey.yieldpercol, honey.StateName)
fig.set_size_inches(16,4)

# %%
sns.boxplot(honey.Region,honey.yieldpercol)

# %%
fig, ax = plt.subplots()
sns.boxplot(honey.year,honey.yieldpercol)
fig.set_size_inches(16,4)
